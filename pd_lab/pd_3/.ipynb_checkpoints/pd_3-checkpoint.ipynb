# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
edj_df = pd.read_html('results_ejudge.html', index_col='User')[0]
edj_df
# Out:
#            Place     A     B     C     D     E     F     G     H  Solved  \
# User
# r0300205       1   9.0  10.0  19.0  20.0  20.0  30.0  30.0  49.0       8
# r0300206       2  10.0   3.0  20.0  20.0  20.0  30.0  30.0  49.0       7
# r0300508       3  10.0  10.0  20.0  20.0  20.0  30.0  29.0   NaN       7
# r0300314       4   9.0   9.0  20.0  20.0  20.0  30.0   9.0  20.0       6
# r0300209       5   8.0  10.0  14.0  20.0  20.0  30.0   0.0  30.0       5
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...     ...
# r0300806  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# r0300812  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# s1393305  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# s1393410  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# user594   75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
#           Score
# User
# r0300205    187
# r0300206    182
# r0300508    139
# r0300314    137
# r0300209    132
# ...         ...
# r0300806      0
# r0300812      0
# s1393305      0
# s1393410      0
# user594       0
#
# [129 rows x 11 columns]

# %%
edj_df.index.to_series().isna().value_counts()
# Out:
# False    129
# Name: User, dtype: int64

# %%
gr_df = pd.read_excel('students_info.xlsx', index_col='login')
gr_df
# Out:
#           group_faculty  group_out
# login
# r0300101              1         35
# r0300102              1         32
# r0300103              1         32
# r0300104              1         32
# r0300105              1         32
# ...                 ...        ...
# NaN                   8         38
# NaN                   8         38
# NaN                   8         38
# NaN                   8         38
# NaN                   8         38
#
# [116 rows x 2 columns]

# %%
gr_df.index.to_series().isna().value_counts()
# Out:
# False    110
# True       6
# Name: login, dtype: int64

# %% [markdown]
# В табличке с группами есть `NaN`-ы. Для 6 человек не указаны логины

# %%
gr_df = gr_df.drop_duplicates().reindex(gr_df.index.dropna().values)
gr_df.index.to_series().isna().value_counts()
# Out:
# False    110
# Name: login, dtype: int64

# %%
ind_gr = gr_df.index
ind_edj = edj_df.index
ind_gr.union(ind_edj).difference(ind_gr.intersection(ind_edj))
# Out:
# Index(['r0300117', 'r0300118', 'r0300120', 'r0300217', 'r0300218', 'r0300317',
#        'r0300318', 'r0300408', 'r0300416', 'r0300417', 'r0300418', 'r0300519',
#        'r0300520', 'r0300606', 'r0300620', 'r0300812', 's1393305', 's1393410',
#        'user594'],
#       dtype='object')

# %% [markdown]
# Есть логины, которые присутствуют в одной таблице, но отсутствуют в другой

# %%
df = edj_df.join(gr_df, how='inner')
df
# Out:
#            Place     A     B     C     D     E     F     G     H  Solved  \
# r0300205       1   9.0  10.0  19.0  20.0  20.0  30.0  30.0  49.0       8
# r0300206       2  10.0   3.0  20.0  20.0  20.0  30.0  30.0  49.0       7
# r0300508       3  10.0  10.0  20.0  20.0  20.0  30.0  29.0   NaN       7
# r0300314       4   9.0   9.0  20.0  20.0  20.0  30.0   9.0  20.0       6
# r0300209       5   8.0  10.0  14.0  20.0  20.0  30.0   0.0  30.0       5
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...     ...
# r0300618  75-129   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# r0300619  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# r0300803  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# r0300805  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
# r0300806  75-129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       0
#
#           Score  group_faculty  group_out
# r0300205    187            NaN        NaN
# r0300206    182            NaN        NaN
# r0300508    139            NaN        NaN
# r0300314    137            3.0       33.0
# r0300209    132            NaN        NaN
# ...         ...            ...        ...
# r0300618      0            NaN        NaN
# r0300619      0            NaN        NaN
# r0300803      0            NaN        NaN
# r0300805      0            NaN        NaN
# r0300806      0            NaN        NaN
#
# [110 rows x 13 columns]

# %%
print('Задача#1')
fig, ax = plt.subplots(1,2)
fig.set_size_inches(8, 5)
df.groupby('group_faculty').mean()['Solved'].plot(kind = 'bar', ax = ax[0])
df.groupby('group_out').mean()['Solved'].plot(kind ='bar', ax = ax[1])
for a in ax:
    a.set_ylim([0, 6])
# Out:
# Задача#1

# %%
g_and_h = df[(df['G']//10>0)|(df['H']//10>0)]
g_and_h
# Out:
#           Place     A     B     C     D     E     F     G     H  Solved  \
# r0300205      1   9.0  10.0  19.0  20.0  20.0  30.0  30.0  49.0       8
# r0300206      2  10.0   3.0  20.0  20.0  20.0  30.0  30.0  49.0       7
# r0300508      3  10.0  10.0  20.0  20.0  20.0  30.0  29.0   NaN       7
# r0300314      4   9.0   9.0  20.0  20.0  20.0  30.0   9.0  20.0       6
# r0300209      5   8.0  10.0  14.0  20.0  20.0  30.0   0.0  30.0       5
# r0300202      6  10.0   9.0  20.0  20.0  20.0  30.0   9.0  10.0       6
# r0300514      7  10.0  10.0  13.0  18.0   NaN  30.0   NaN  30.0       4
# r0300414     12  10.0   6.0  20.0  20.0   NaN  30.0   NaN  15.0       4
# r0300511     18   9.0   9.0   NaN   NaN   NaN  30.0   NaN  29.0       3
# r0300212  20-21  10.0   3.0  20.0   NaN  20.0   NaN   NaN  20.0       3
# r0300301     24   9.0   5.0   NaN   NaN   NaN  23.0   8.0  23.0       1
# r0300515     26  10.0   NaN   NaN   NaN   NaN  30.0   NaN  25.0       2
#
#           Score  group_faculty  group_out
# r0300205    187            NaN        NaN
# r0300206    182            NaN        NaN
# r0300508    139            NaN        NaN
# r0300314    137            3.0       33.0
# r0300209    132            NaN        NaN
# r0300202    128            2.0       33.0
# r0300514    111            NaN        NaN
# r0300414    101            NaN        NaN
# r0300511     77            NaN        NaN
# r0300212     73            NaN        NaN
# r0300301     68            3.0       35.0
# r0300515     65            NaN        NaN

# %%
print('Задача#2\n\nПрошедшие хотя бы один тест в последних двух задачах пришли из факультетских групп:')
for gr in g_and_h['group_faculty'].drop_duplicates().values:
    print('\t'+str(gr))
print('И попали в группы по информатике:')
for gr in g_and_h['group_out'].drop_duplicates().values:
    print('\t'+str(gr))
# Out:
# Задача#2
#
# Прошедшие хотя бы один тест в последних двух задачах пришли из факультетских групп:
# 	nan
# 	3.0
# 	2.0
# И попали в группы по информатике:
# 	nan
# 	33.0
# 	35.0
