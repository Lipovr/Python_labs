# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("students.csv", sep=';', names=['prep', 'group', 'mark'])
df
# Out:
#      prep  group  mark
# 0   prep1    751     8
# 1   prep1    751     5
# 2   prep1    751     4
# 3   prep1    751     5
# 4   prep1    751     4
# ..    ...    ...   ...
# 95  prep7    755     8
# 96  prep7    755     5
# 97  prep7    756     5
# 98  prep7    756     5
# 99  prep7    756     8
#
# [100 rows x 3 columns]

# %%
df[['group', 'mark']] = df[['group', 'mark']].applymap(int)

# %%
df['prep'].value_counts()
# Out:
# prep2    17
# prep1    17
# prep7    16
# prep3    14
# prep5    13
# prep6    12
# prep4    11
# Name: prep, dtype: int64

# %%
df['group'].value_counts()
# Out:
# 756    18
# 754    18
# 755    16
# 753    16
# 752    16
# 751    16
# Name: group, dtype: int64

# %%
pr = df.groupby(['prep', 'mark']).size().unstack().fillna(0).applymap(int)
pr
# Out:
# mark   3   4   5   6   7   8   9   10
# prep
# prep1   1   3   5   1   3   3   0   1
# prep2   0   0   3   1   6   2   4   1
# prep3   1   1   1   1   2   4   2   2
# prep4   2   5   2   2   0   0   0   0
# prep5   0   0   4   4   1   3   1   0
# prep6   0   2   2   1   4   0   2   1
# prep7   0   0   6   0   2   5   0   3

# %%
gr = df.groupby(['group', 'mark']).size().unstack().fillna(0).applymap(int)
gr
# Out:
# mark   3   4   5   6   7   8   9   10
# group
# 751     1   3   4   0   2   3   3   0
# 752     0   2   3   1   5   2   1   2
# 753     2   2   1   0   4   4   1   2
# 754     1   3   4   3   2   2   1   2
# 755     0   0   4   3   3   4   2   0
# 756     0   1   7   3   2   2   1   2

# %%
cmap = plt.get_cmap('YlGn')
colors = cmap(np.linspace(0,1,8))

# %%
def mark_plot(grouped, colors, title):
    fig1, ax1 = plt.subplots()
    for i in range(3,11):
        ax1.bar(grouped.index, grouped.loc[:, i].values, bottom=(grouped.loc[:, :i-1].values.sum(axis=1) if i>3 else None), label=i, color = colors[i-3])
    handles, labels = ax1.get_legend_handles_labels()
    ax1.legend(handles[::-1], labels[::-1], title='mark', loc='upper right')
    ax1.set_title(title)

# %%
mark_plot(pr, colors, 'Marks per prep')

# %%
mark_plot(gr, colors, 'Marks per group')

# %%
gr_norm = gr.apply(lambda x: {i:float(x[i])/sum(x) for i in range(3,11)}, axis =1, result_type='expand')
gr_norm
# Out:
#              3         4         5         6         7         8         9   \
# group
# 751    0.062500  0.187500  0.250000  0.000000  0.125000  0.187500  0.187500
# 752    0.000000  0.125000  0.187500  0.062500  0.312500  0.125000  0.062500
# 753    0.125000  0.125000  0.062500  0.000000  0.250000  0.250000  0.062500
# 754    0.055556  0.166667  0.222222  0.166667  0.111111  0.111111  0.055556
# 755    0.000000  0.000000  0.250000  0.187500  0.187500  0.250000  0.125000
# 756    0.000000  0.055556  0.388889  0.166667  0.111111  0.111111  0.055556
#
#              10
# group
# 751    0.000000
# 752    0.125000
# 753    0.125000
# 754    0.111111
# 755    0.000000
# 756    0.111111

# %%
pr_norm = pr.apply(lambda x: {i:float(x[i])/sum(x) for i in range(3,11)}, axis =1, result_type='expand')
pr_norm
# Out:
#              3         4         5         6         7         8         9   \
# prep
# prep1  0.058824  0.176471  0.294118  0.058824  0.176471  0.176471  0.000000
# prep2  0.000000  0.000000  0.176471  0.058824  0.352941  0.117647  0.235294
# prep3  0.071429  0.071429  0.071429  0.071429  0.142857  0.285714  0.142857
# prep4  0.181818  0.454545  0.181818  0.181818  0.000000  0.000000  0.000000
# prep5  0.000000  0.000000  0.307692  0.307692  0.076923  0.230769  0.076923
# prep6  0.000000  0.166667  0.166667  0.083333  0.333333  0.000000  0.166667
# prep7  0.000000  0.000000  0.375000  0.000000  0.125000  0.312500  0.000000
#
#              10
# prep
# prep1  0.058824
# prep2  0.058824
# prep3  0.142857
# prep4  0.000000
# prep5  0.000000
# prep6  0.083333
# prep7  0.187500

# %%
mark_plot(pr_norm, colors, 'Marks per prep normed')

# %%
mark_plot(gr_norm, colors, 'Marks per group normed')
